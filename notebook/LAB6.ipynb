# %% [markdown]
# # Link to GitHub -
# ## https://github.com/TimurCravtov/PracticeRepository

# %%
# %%bash
#
# rm -r sample_data
#
# cat > README.md
# ## This is GitHub repository for EEBG project.
# This folders coutais three other folders: *summarydata*, *notebook* and *figure* with descriptive names. Each folder has its own README files, so you wont get lost

# %%
# %%bash
#
# mkdir summarydata
#
# cd summarydata
# wget wget -nv -O titanic.csv 'https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#
# cat > README.md
# ## Hello, it's me again. You are in summary data folder.
# This folder, apart from README file, contains *titanic.csv* file taken from seaborn sample data
# Out:
# mkdir: cannot create directory ‘summarydata’: File exists
# wget: unable to resolve host address ‘wget’
# 2024-06-28 12:23:57 URL:https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv [57018/57018] -> "titanic.csv" [1]
# FINISHED --2024-06-28 12:23:57--
# Total wall clock time: 0.08s
# Downloaded: 1 files, 56K in 0.01s (4.39 MB/s)

# %%
# %%bash
#
# mkdir notebook
#
# cd notebook
#
# gdown https://drive.google.com/uc?id=1szqKNsGPlXmseUji5rI3ZiRVmadNDsmL -O LAB5.ipynb
#
# cat > README.md
# ## Guess who? You are in notebook folder
# This folder contains
# Out:
# mkdir: cannot create directory ‘notebook’: File exists
# Downloading...
# From: https://drive.google.com/uc?id=1szqKNsGPlXmseUji5rI3ZiRVmadNDsmL
# To: /content/notebook/LAB5.ipynb
# 100%|██████████| 304k/304k [00:00<00:00, 68.0MB/s]

# %%
# %%bash
#
# mkdir figure
# cd figure
#
# cat > README.md
# ## Hello again!! This is figure directory
#
# This directory is supposed to have all the figures I made, but I am not sure if it will. If you cannot see any figures, that means that notebook was great and all the figures are displayed there.

# %%
# %%bash
#
# git init
# git add .
# git commit -m "initial commit"
#
# git remote add origin git@github.com:TimurCravtov/PracticeRepository.git
#
# ssh-keygen -t ed25519 -C 'timurcravtov@gmail.com' -f ~/.ssh/id_ed25519 -P ''
# cat > ~/.ssh/config
# Host *
#   AddKeysToAgent yes
#   IdentityFile ~/.ssh/id_ed25519
# Out:
# Initialized empty Git repository in /content/.git/
# [master (root-commit) 54d5965] initial commit
#  6 files changed, 1044 insertions(+)
#  create mode 100644 README.md
#  create mode 100644 figure/README.md
#  create mode 100644 notebook/LAB5.ipynb
#  create mode 100644 notebook/README.md
#  create mode 100644 summarydata/README.md
#  create mode 100644 summarydata/titanic.csv
# Generating public/private ed25519 key pair.
# /root/.ssh/id_ed25519 already exists.
# Overwrite (y/n)?
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# ...

# %%
# %%bash
#
# git config --global user.email "timurcravtov04@gmail.com"
# git config --global user.name "Timur Cravtov"

# %%
# %%bash
#
# cat > .gitignore
# .*
# .gitignore

# %%
# %%bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_ed25519
# Out:
# Agent pid 9143
# Identity added: /root/.ssh/id_ed25519 (timurcravtov@gmail.com)

# %%
# %%bash
# cat ~/.ssh/id_ed25519.pub
# Out:
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIBGMeuvQTAZpANJOcnjKq/If+qrej4teJ7jPRI+9JjUs timurcravtov@gmail.com

# %%
# %%bash
# ssh -o "StrictHostKeyChecking no" -T git@github.com
# Out:
# ...
# Hi TimurCravtov! You've successfully authenticated, but GitHub does not provide shell access.
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-30-092455711042> in <cell line: 1>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'ssh -o "StrictHostKeyChecking no" -T git@github.com\n')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     332     if line and not cell:
#     333       cell = ' '
# --> 334     return super().run_cell_magic(magic_name, line, cell)
#     335
#     336
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
# ...

# %%
# %%bash
#
# git remote add origin https://github.com/TimurCravtov/PracticeRepository
# git branch -M main
# git push -u origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# error: remote origin already exists.
# To github.com:TimurCravtov/PracticeRepository.git
#  * [new branch]      main -> main

# %%
# %%bash
#
# git add .
# git commit -m "updated notebook5"
# git push origin main
# Out:
# [main 34bf988] updated notebook5
#  1 file changed, 1 insertion(+), 143 deletions(-)
#  rewrite notebook/LAB5.ipynb (95%)
# To github.com:TimurCravtov/PracticeRepository.git
#    54d5965..34bf988  main -> main

# %%
# %%bash
#
# cd notebook
#
# gdown https://drive.google.com/uc?id=1VeZKMZnSBflUldimM-Msb2SKbrMQ6vhN -O LAB3.ipynb
# gdown https://drive.google.com/uc?id=17g-4XHD35Z339aCVxR__Ni-a6FoGaAoV -O LAB4.ipynb
# gdown https://drive.google.com/uc?id=1Nwv4JZbg6l2NO9Un4uay0_y9RBApeFrR -O LAB1and2.ipynb
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VeZKMZnSBflUldimM-Msb2SKbrMQ6vhN
# To: /content/notebook/LAB3.ipynb
# 100%|██████████| 1.08M/1.08M [00:00<00:00, 114MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=17g-4XHD35Z339aCVxR__Ni-a6FoGaAoV
# To: /content/notebook/LAB4.ipynb
# 100%|██████████| 108k/108k [00:00<00:00, 67.2MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1Nwv4JZbg6l2NO9Un4uay0_y9RBApeFrR
# To: /content/notebook/LAB1and2.ipynb
# 100%|██████████| 4.66k/4.66k [00:00<00:00, 10.2MB/s]

# %%
# %%bash
#
# git add .
# git commit -m "added all the labs"
#
# git push origin main
# Out:
# [main 6d2cbe0] added all the labs
#  3 files changed, 3 insertions(+)
#  create mode 100644 notebook/LAB1and2.ipynb
#  create mode 100644 notebook/LAB3.ipynb
#  create mode 100644 notebook/LAB4.ipynb
# To github.com:TimurCravtov/PracticeRepository.git
#    34bf988..6d2cbe0  main -> main

# %%
# %%bash
#
# cd notebook
#
# cat > README.md
#
# ## Guess who? You are in notebook folder
#
# This folder contains all the labs created during these days in *ipynb* format
# - LAB1and2 - first and second lab. First lab was on creating desired folder structure using bash commands. The second is getting data using wget and manipulate it
# - LAB3 - it's a copy of given notebook. The task was to fix the mistakes
# - LAB4 - pandas visualisation
# - LAB5 - small lab on seaborn visualisation.
# - LAB6 - this->lab which focused on Git and GitHub

# %% [markdown]
# This script is the last one, pushed *this* notebook

# %%
# %%bash
#
# gdown https://drive.google.com/uc?id=16q7HAFCH9lkLOfg0cuJ-C7USxar0O9XL -O LAB6.ipynb
#
# git add .
# git commit -m "last one!!"
# git push origin main
# Out:
# [main 0fab162] last one!!
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite LAB6.ipynb (95%)
# Downloading...
# From: https://drive.google.com/uc?id=16q7HAFCH9lkLOfg0cuJ-C7USxar0O9XL
# To: /content/LAB6.ipynb
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 40.6MB/s]
# To github.com:TimurCravtov/PracticeRepository.git
#    24563e7..0fab162  main -> main
